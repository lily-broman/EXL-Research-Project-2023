# %%
import pandas as pd
d=pd.read_csv("C:\\Users\\LilyB\Desktop\\austin_waste_and_diversion.csv")
df=pd.DataFrame(d)

# %%
print(df)
# Out:
#         dropoff_site  load_id            load_time                  load_type  \
# 0                MRF   328118  2009-05-27 12:55:00  RECYCLING - SINGLE STREAM
# 1        BRAKER SITE   308336  2008-12-16 10:55:00                   SWEEPING
# 2          TDS - MRF   541514  2012-09-06 13:56:00  RECYCLING - SINGLE STREAM
# 3       TDS LANDFILL   689059  2016-03-14 07:56:00                   SWEEPING
# 4       HORNSBY BEND   108272  2004-12-02 15:29:00              YARD TRIMMING
# ...              ...      ...                  ...                        ...
# 564398     TDS - MRF   619855  2014-07-22 13:34:00  RECYCLING - SINGLE STREAM
# 564399  TDS LANDFILL   265305  2008-02-13 11:15:00        GARBAGE COLLECTIONS
# 564400           MRF   240187  2007-08-23 14:18:00       RECYCLING - COMINGLE
# 564401           MRF   353867  2010-01-12 11:39:00  RECYCLING - SINGLE STREAM
# 564402     TDS - MRF   541674  2012-09-10 10:20:00  RECYCLING - SINGLE STREAM
#
# ...

# %%
display(df)
# Out:
#         dropoff_site  load_id            load_time                  load_type  \
# 0                MRF   328118  2009-05-27 12:55:00  RECYCLING - SINGLE STREAM
# 1        BRAKER SITE   308336  2008-12-16 10:55:00                   SWEEPING
# 2          TDS - MRF   541514  2012-09-06 13:56:00  RECYCLING - SINGLE STREAM
# 3       TDS LANDFILL   689059  2016-03-14 07:56:00                   SWEEPING
# 4       HORNSBY BEND   108272  2004-12-02 15:29:00              YARD TRIMMING
# ...              ...      ...                  ...                        ...
# 564398     TDS - MRF   619855  2014-07-22 13:34:00  RECYCLING - SINGLE STREAM
# 564399  TDS LANDFILL   265305  2008-02-13 11:15:00        GARBAGE COLLECTIONS
# 564400           MRF   240187  2007-08-23 14:18:00       RECYCLING - COMINGLE
# 564401           MRF   353867  2010-01-12 11:39:00  RECYCLING - SINGLE STREAM
# 564402     TDS - MRF   541674  2012-09-10 10:20:00  RECYCLING - SINGLE STREAM
#
# ...
